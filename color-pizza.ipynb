# %%
from urllib.request import urlopen

import matplotlib.pyplot as plt
from PIL import Image

from mplsoccer import PyPizza, add_image, FontManager
import soccerdata as sd
# Out:
# [11/14/23 00:47:44] INFO     No custom team name replacements found. You can configure these in       ]8;id=996922;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=121527;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_config.py#84\84]8;;\
#                              C:\Users\szymo\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=281799;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=513050;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_config.py#162\162]8;;\
#                              C:\Users\szymo\soccerdata\config\league_dict.json.

# %%
font_normal = FontManager('https://raw.githubusercontent.com/google/fonts/main/apache/roboto/'
                          'Roboto%5Bwdth,wght%5D.ttf')
font_italic = FontManager('https://raw.githubusercontent.com/google/fonts/main/apache/roboto/'
                          'Roboto-Italic%5Bwdth,wght%5D.ttf')
font_bold = FontManager('https://raw.githubusercontent.com/google/fonts/main/apache/robotoslab/'
                        'RobotoSlab%5Bwght%5D.ttf')

# %%
URL = "https://raw.githubusercontent.com/andrewRowlinson/mplsoccer-assets/main/fdj_cropped.png"
fdj_cropped = Image.open(urlopen(URL))

# %%
fbref = sd.FBref(leagues="ESP-La Liga", seasons=2023)
print(fbref.__doc__)
# Out:
# [11/14/23 00:48:06] INFO     Saving cached data to C:\Users\szymo\soccerdata\data\FBref               ]8;id=124570;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=560055;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_common.py#89\89]8;;\
# Provides pd.DataFrames from data at http://fbref.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/FBref``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include. For efficiently reading data from the Top-5
#         European leagues, use "Big 5 European Leagues Combined".
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or dict or list(dict) or callable, optional
# ...

# %%
player_match_stats = fbref.read_player_match_stats(stat_type="passing", match_id='ff452d69')
player_match_stats.head()
# Out:
# [11/14/23 00:50:06] INFO     [1/1] Retrieving game with id=ff452d69                                    ]8;id=571275;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\fbref.py\fbref.py]8;;\:]8;id=495800;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\fbref.py#771\771]8;;\
#                                                                                         jersey_number  \
#
# league      season game                                  team           player
# ESP-La Liga 2324   2023-11-05 Real Madrid-Rayo Vallecano Rayo Vallecano Abdul Mumin                16
#                                                                         Alfonso Espino             12
#                                                                         Andrei Ratiu                2
#                                                                         Bebé                       10
# ...

# %%
specific_player_data = player_match_stats.xs('Jude Bellingham', level='player')
specific_player_data.head()
# Out:
#                                                                       jersey_number_  \
# league      season game                                  team
# ESP-La Liga 2324   2023-11-05 Real Madrid-Rayo Vallecano Real Madrid               5
#
#                                                                      nation_  \
# league      season game                                  team
# ESP-La Liga 2324   2023-11-05 Real Madrid-Rayo Vallecano Real Madrid     ENG
#
#                                                                      pos_  \
# league      season game                                  team
# ESP-La Liga 2324   2023-11-05 Real Madrid-Rayo Vallecano Real Madrid   AM
#
#                                                                         age_  \
# league      season game                                  team
# ESP-La Liga 2324   2023-11-05 Real Madrid-Rayo Vallecano Real Madrid  20-129
#
#                                                                       min_  \
# ...

# %%
# parameter list
params = [
    'Passes Completed', 'Passes Attempted', 'Pass Completion %', 'Total Passing Distance', 'Progressive Distance', 'Passes Completed (Short)', 'Passes Attempted (Short)', 'Pass Completion % (Short)', 'Passes Completed (Medium)', 'Passes Attempted (Medium)', 'Pass Completion % (Medium)', 'Passes Completed (Long)', 'Passes Attempted (Long)', 'Pass Completion % (Long)%'
]

# value list
# The values are taken from the excellent fbref website (supplied by StatsBomb)

values = specific_player_data[['Total_Cmp', 'Total_Att', 'Total_Cmp%', 'Total_TotDist', 'Total_PrgDist', 'Short_Cmp', 'Short_Att', 'Short_Cmp%', 'Medium_Cmp', 'Medium_Att', 'Medium_Cmp%', 'Long_Cmp', 'Long_Att', 'Long_Cmp%']].values.flatten().tolist()

#values = [
#    70, 77, 74, 68, 60,
#    96, 89, 97, 92, 94,
#    16, 19, 56, 53, 94
#]

# color for the slices and text
slice_colors = ["#1A78CF"] * 5 + ["#FF9300"] * 3 + ["#D70232"] * 3 + ["#F2F2F2"] * 3
text_colors = ["#000000"] * 10 + ["#F2F2F2"] * 4

# instantiate PyPizza class
baker = PyPizza(
    params=params,                  # list of parameters
    background_color="#EBEBE9",     # background color
    straight_line_color="#EBEBE9",  # color for straight lines
    straight_line_lw=1,             # linewidth for straight lines
    last_circle_lw=0,               # linewidth of last circle
    other_circle_lw=0,              # linewidth for other circles
    inner_circle_size=20            # size of inner circle
)

# plot pizza
fig, ax = baker.make_pizza(
    values,                          # list of values
    figsize=(8, 8.5),                # adjust figsize according to your need
    color_blank_space="same",        # use same color to fill blank space
    slice_colors=slice_colors,       # color for individual slices
    value_colors=text_colors,        # color for the value-text
    value_bck_colors=slice_colors,   # color for the blank spaces
    blank_alpha=0.4,                 # alpha for blank-space colors
    kwargs_slices=dict(
        edgecolor="#F2F2F2", zorder=2, linewidth=1
    ),                               # values to be used when plotting slices
    kwargs_params=dict(
        color="#000000", fontsize=11,
        fontproperties=font_normal.prop, va="center"
    ),                               # values to be used when adding parameter
    kwargs_values=dict(
        color="#000000", fontsize=11,
        fontproperties=font_normal.prop, zorder=3,
        bbox=dict(
            edgecolor="#000000", facecolor="cornflowerblue",
            boxstyle="round,pad=0.2", lw=1
        )
    )                                # values to be used when adding parameter-values
)

# add title
fig.text(
    0.515, 0.975, "Jude Bellingham - Real Madrid", size=16,
    ha="center", fontproperties=font_bold.prop, color="#000000"
)

# add subtitle
fig.text(
    0.515, 0.953,
    "Percentile Rank vs Top-Five League Midfielders | Season 2020-21",
    size=13,
    ha="center", fontproperties=font_bold.prop, color="#000000"
)

# add credits
CREDIT_1 = "data: viz fbref"
CREDIT_2 = "inspired by: @skszymon"

fig.text(
    0.99, 0.02, f"{CREDIT_1}\n{CREDIT_2}", size=9,
    fontproperties=font_italic.prop, color="#000000",
    ha="right"
)

# add text
fig.text(
    0.34, 0.925, "Attacking        Possession       Defending", size=14,
    fontproperties=font_bold.prop, color="#000000"
)

# add rectangles
fig.patches.extend([
    plt.Rectangle(
        (0.31, 0.9225), 0.025, 0.021, fill=True, color="#1a78cf",
        transform=fig.transFigure, figure=fig
    ),
    plt.Rectangle(
        (0.462, 0.9225), 0.025, 0.021, fill=True, color="#ff9300",
        transform=fig.transFigure, figure=fig
    ),
    plt.Rectangle(
        (0.632, 0.9225), 0.025, 0.021, fill=True, color="#d70232",
        transform=fig.transFigure, figure=fig
    ),
])

# add image
ax_image = add_image(
    fdj_cropped, fig, left=0.4478, bottom=0.4315, width=0.13, height=0.127
)   # these values might differ when you are plotting

plt.show()
