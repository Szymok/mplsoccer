# %%
import soccerdata as sd
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# [10/11/23 01:32:01] INFO     No custom team name replacements found. You can configure these in       ]8;id=719473;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=80857;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_config.py#84\84]8;;\
#                              C:\Users\szymo\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=102640;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=857907;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_config.py#162\162]8;;\
#                              C:\Users\szymo\soccerdata\config\league_dict.json.

# %%
fbref = sd.FBref(leagues="ESP-La Liga", seasons=2324)
print(fbref.__doc__)
# Out:
# [10/11/23 01:32:09] INFO     Saving cached data to C:\Users\szymo\soccerdata\data\FBref               ]8;id=620698;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=755488;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_common.py#89\89]8;;\
# Provides pd.DataFrames from data at http://fbref.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/FBref``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include. For efficiently reading data from the Top-5
#         European leagues, use "Big 5 European Leagues Combined".
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or dict or list(dict) or callable, optional
#         Use a proxy to hide your IP address. Valid options are:
#             - "tor": Uses the Tor network. Tor should be running in
#               the background on port 9050.
#             - dict: A dictionary with the proxy to use. The dict should be
#               a mapping of supported protocols to proxy addresses. For example::
#
#                   {
#                       'http': 'http://10.10.1.10:3128',
#                       'https': 'http://10.10.1.10:1080',
#                   }
#
#             - list(dict): A list of proxies to choose from. A different proxy will
#               be selected from this list after failed requests, allowing rotating
#               proxies.
#             - callable: A function that returns a valid proxy. This function will
#               be called after failed requests, allowing rotating proxies.
#     no_cache : bool
#         If True, will not use cached data.
#     no_store : bool
#         If True, will not store downloaded data.
#     data_dir : Path
#         Path to directory where data will be cached.

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="passing")
# Out:
#                                    players_used 90s Total                      \
#                                                       Cmp   Att  Cmp% TotDist
# league      season team
# ESP-La Liga 2324   Alavés                    22   6  1596  2321  68.8   30783
#                    Almería                   23   6  2434  2968  82.0   43660
#                    Athletic Club             22   6  2318  3017  76.8   40592
#                    Atlético Madrid           22   5  1937  2404  80.6   32884
#                    Barcelona                 23   6  3826  4298  89.0   59631
#                    Betis                     25   6  2376  2885  82.4   39740
#                    Celta Vigo                22   6  1998  2624  76.1   33936
#                    Cádiz                     22   6  1337  1930  69.3   27050
#                    Getafe                    23   6  1270  1933  65.7   25976
#                    Girona                    20   6  2466  2970  83.0   41912
#
#                                            Short             Medium        \
#                                    PrgDist   Cmp   Att  Cmp%    Cmp   Att
# league      season team
# ESP-La Liga 2324   Alavés            13958   712   877  81.2    598   816
#                    Almería           14992  1069  1180  90.6   1084  1236
#                    Athletic Club     15841  1086  1247  87.1    965  1150
#                    Atlético Madrid   12695   985  1114  88.4    701   810
#                    Barcelona         18460  2105  2243  93.8   1401  1549
#                    Betis             14777  1185  1305  90.8    867   990
#                    Celta Vigo        13482   945  1096  86.2    820   967
#                    Cádiz             11760   536   656  81.7    535   684
#                    Getafe            12379   544   660  82.4    427   622
#                    Girona            15023  1177  1275  92.3   1022  1151
#
#                                          Long            Ast  xAG   xA A-xAG  \
#                                     Cmp%  Cmp  Att  Cmp%
# league      season team
# ESP-La Liga 2324   Alavés           73.3  241  493  48.9   4  4.2  4.1  -0.2
#                    Almería          87.7  231  418  55.3   4  7.7  5.9  -3.7
#                    Athletic Club    83.9  217  460  47.2   7  6.2  6.1   0.8
#                    Atlético Madrid  86.5  198  338  58.6   8  6.2  5.9   1.8
#                    Barcelona        90.4  229  337  68.0  11  9.4  9.4   1.6
#                    Betis            87.6  231  399  57.9   3  5.3  5.7  -2.3
#                    Celta Vigo       84.8  170  387  43.9   4  6.4  7.4  -2.4
#                    Cádiz            78.2  222  468  47.4   3  3.2  4.2  -0.2
#                    Getafe           68.6  246  520  47.3   5  3.2  4.1   1.8
#                    Girona           88.8  193  384  50.3  11  8.4  7.8   2.6
#
#                                     KP  1/3 PPA CrsPA PrgP  \
#
# league      season team
# ESP-La Liga 2324   Alavés           55  148  39    19  199
#                    Almería          69  172  39    20  207
#                    Athletic Club    48  196  49    17  246
#                    Atlético Madrid  42  156  51    13  205
#                    Barcelona        75  327  73    16  326
#                    Betis            65  168  60    12  237
#                    Celta Vigo       71  180  52    16  213
#                    Cádiz            42  117  28    16  128
#                    Getafe           42  126  33    15  128
#                    Girona           53  164  48     9  175
#
#                                                                           url
#
# league      season team
# ESP-La Liga 2324   Alavés                    /en/squads/8d6fd021/Alaves-Stats
#                    Almería                  /en/squads/78ecf4bb/Almeria-Stats
#                    Athletic Club      /en/squads/2b390eca/Athletic-Club-Stats
#                    Atlético Madrid  /en/squads/db3b9613/Atletico-Madrid-Stats
#                    Barcelona              /en/squads/206d90db/Barcelona-Stats
#                    Betis                 /en/squads/fc536746/Real-Betis-Stats
#                    Celta Vigo            /en/squads/f25da7fb/Celta-Vigo-Stats
#                    Cádiz                      /en/squads/ee7c297c/Cadiz-Stats
#                    Getafe                    /en/squads/7848bd64/Getafe-Stats
#                    Girona                    /en/squads/9024a00a/Girona-Stats

# %%
team_season_stats.head(20)
# Out:
#                                    players_used 90s Total                      \
#                                                       Cmp   Att  Cmp% TotDist
# league      season team
# ESP-La Liga 2324   Alavés                    22   6  1596  2321  68.8   30783
#                    Almería                   23   6  2434  2968  82.0   43660
#                    Granada          83.0  258  508  50.8   7  4.4  4.6   2.6
#                    Las Palmas       87.0  174  358  48.6   1  3.7  4.3  -2.7
#                    Mallorca         79.4  203  421  48.2   4  4.3  3.6  -0.3
#                    Osasuna          78.8  298  605  49.3   3  4.1  5.2  -1.1
#                    Rayo Vallecano   83.4  282  517  54.5   4  5.8  5.0  -1.8
#                    Real Madrid      89.8  266  405  65.7   7  6.9  9.8   0.1
#                    Real Sociedad    85.5  216  405  53.3   8  6.2  5.2   1.8
#                    Sevilla          79.0  214  429  49.9   2  3.8  5.5  -1.8
#                    Valencia         85.5  180  420  42.9   6  5.0  4.0   1.0
#                    Villarreal       89.2  248  400  62.0   7  5.8  6.3   1.2
#
#                                     KP  1/3 PPA CrsPA PrgP  \
#
# league      season team
# ESP-La Liga 2324   Alavés           55  148  39    19  199
#                    Almería          69  172  39    20  207
#                    Athletic Club    48  196  49    17  246
#                    Atlético Madrid  42  156  51    13  205
#                    Barcelona        75  327  73    16  326
#                    Betis            65  168  60    12  237
#                    Celta Vigo       71  180  52    16  213
#                    Cádiz            42  117  28    16  128
#                    Getafe           42  126  33    15  128
#                    Girona           53  164  48     9  175
#                    Granada          40  121  35    11  142
#                    Las Palmas       45  186  38     4  216
#                    Mallorca         43  115  27    12  143
#                    Osasuna          49  195  34    15  195
#                    Rayo Vallecano   64  183  51    14  199
#                    Real Madrid      87  299  80    13  350
#                    Real Sociedad    56  187  33     7  207
#                    Sevilla          55  161  43    20  204
#                    Valencia         50  138  36     8  188
#                    Villarreal       57  215  62    11  262
#
#                                                                           url
#
# league      season team
# ESP-La Liga 2324   Alavés                    /en/squads/8d6fd021/Alaves-Stats
#                    Almería                  /en/squads/78ecf4bb/Almeria-Stats
#                    Athletic Club      /en/squads/2b390eca/Athletic-Club-Stats
#                    Atlético Madrid  /en/squads/db3b9613/Atletico-Madrid-Stats
#                    Barcelona              /en/squads/206d90db/Barcelona-Stats
#                    Betis                 /en/squads/fc536746/Real-Betis-Stats
#                    Celta Vigo            /en/squads/f25da7fb/Celta-Vigo-Stats
#                    Cádiz                      /en/squads/ee7c297c/Cadiz-Stats
#                    Getafe                    /en/squads/7848bd64/Getafe-Stats
#                    Girona                    /en/squads/9024a00a/Girona-Stats
#                    Granada                  /en/squads/a0435291/Granada-Stats
#                    Las Palmas            /en/squads/0049d422/Las-Palmas-Stats
#                    Mallorca                /en/squads/2aa12281/Mallorca-Stats
#                    Osasuna                  /en/squads/03c57e2b/Osasuna-Stats
#                    Rayo Vallecano    /en/squads/98e8af82/Rayo-Vallecano-Stats
#                    Real Madrid          /en/squads/53a2f082/Real-Madrid-Stats
#                    Real Sociedad      /en/squads/e31d1cd9/Real-Sociedad-Stats
#                    Sevilla                  /en/squads/ad2be733/Sevilla-Stats
#                    Valencia                /en/squads/dcc91a7b/Valencia-Stats
#                    Villarreal            /en/squads/2a8183b3/Villarreal-Stats
