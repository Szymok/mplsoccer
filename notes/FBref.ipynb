# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
# %env SOCCERDATA_LOGLEVEL=ERROR
# %env SOCCERDATA_NOCACHE=True
# %env SOCCERDATA_NOSTORE=True
# Out:
# env: SOCCERDATA_LOGLEVEL=ERROR
# env: SOCCERDATA_NOCACHE=True
# env: SOCCERDATA_NOSTORE=True

# %%
import soccerdata as sd
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # FBref

# %%
fbref = sd.FBref(leagues="ESP-La Liga", seasons=2023)
print(fbref.__doc__)
# Out:
# Provides pd.DataFrames from data at http://fbref.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/FBref``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include. For efficiently reading data from the Top-5
#         European leagues, use "Big 5 European Leagues Combined".
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or dict or list(dict) or callable, optional
#         Use a proxy to hide your IP address. Valid options are:
#             - "tor": Uses the Tor network. Tor should be running in
#               the background on port 9050.
#             - dict: A dictionary with the proxy to use. The dict should be
#               a mapping of supported protocols to proxy addresses. For example::
#
#                   {
# ...

# %% [markdown]
# ## Team season stats

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="passing")
team_season_stats.head()
# Out:
#                                    players_used 90s  Total               \
#                                                        Cmp    Att  Cmp%
# league      season team
# ESP-La Liga 2324   Alavés                    27  20   5481   7582  72.3
#                    Almería                   28  19   6380   8359  76.3
#                    Athletic Club             25  20   7275   9561  76.1
#                    Atlético Madrid           23  19   8764  10625  82.5
#                    Barcelona                 26  19  10682  12279  87.0
#
#                                                    Short             Medium  \
#                                    TotDist PrgDist   Cmp   Att  Cmp%    Cmp
# league      season team
# ESP-La Liga 2324   Alavés           102073   43720  2506  2953  84.9   2125
#                    Almería          117049   43358  2703  3134  86.2   2810
#                    Athletic Club    130000   50923  3255  3792  85.8   3117
# ...

# %% [markdown]
# ## Team match stats

# %% [markdown]
# ## Player season stats

# %%
player_season_stats = fbref.read_player_season_stats(stat_type="standard")
player_season_stats.head()
# Out:
#                                               nation    pos     age  born  \
#
# league      season team   player
# ESP-La Liga 2324   Alavés Abdel Abqar            MAR     DF  24-310  1999
#                           Abderrahman Rebbach    ALG  FW,MF  25-156  1998
#                           Aleksandar Sedlar      SRB     DF  32-032  1991
#                           Alex Sola              ESP  FW,MF  24-219  1999
#                           Ander Guevara          ESP     MF  26-191  1997
#
#                                               Playing Time                     \
#                                                         MP Starts   Min   90s
# league      season team   player
# ESP-La Liga 2324   Alavés Abdel Abqar                   14     14  1254  13.9
#                           Abderrahman Rebbach           16      6   582   6.5
#                           Aleksandar Sedlar             11     11   946  10.5
# ...

# %% [markdown]
# ## Player match stats

# %%
player_match_stats = fbref.read_player_match_stats(stat_type="passing", match_id='872da7fb')
player_match_stats.head()
# Out:
#                                                                                  jersey_number  \
#
# league      season game                         team       player
# ESP-La Liga 2324   2023-12-09 Betis-Real Madrid Real Betis Abdessamad Ezzalzouli             7
#                                                            Abner                            20
#                                                            Aitor Ruibal                     24
#                                                            Andrés Guardado                  18
#                                                            Assane Diao                      38
#
#                                                                                  nation  \
#
# league      season game                         team       player
# ESP-La Liga 2324   2023-12-09 Betis-Real Madrid Real Betis Abdessamad Ezzalzouli    MAR
#                                                            Abner                    BRA
# ...

# %% [markdown]
# ## Game schedule

# %%
epl_schedule = fbref.read_schedule()
epl_schedule.head()
# Out:
#                                                          week  day       date  \
# league      season game
# ESP-La Liga 2324   2023-08-11 Almería-Rayo Vallecano        1  Fri 2023-08-11
#                    2023-08-11 Sevilla-Valencia              1  Fri 2023-08-11
#                    2023-08-12 Athletic Club-Real Madrid     1  Sat 2023-08-12
#                    2023-08-12 Las Palmas-Mallorca           1  Sat 2023-08-12
#                    2023-08-12 Real Sociedad-Girona          1  Sat 2023-08-12
#
#                                                           time      home_team  \
# league      season game
# ESP-La Liga 2324   2023-08-11 Almería-Rayo Vallecano     19:30        Almería
#                    2023-08-11 Sevilla-Valencia           22:00        Sevilla
#                    2023-08-12 Athletic Club-Real Madrid  21:30  Athletic Club
#                    2023-08-12 Las Palmas-Mallorca        18:30     Las Palmas
# ...

# %% [markdown]
# ## Line ups

# %%
lineups = fbref.read_lineup(match_id='872da7fb')
lineups.head()
# Out:
# [01/15/24 01:21:16] ERROR    Error while scraping https://fbref.com/en/comps/. Retrying... (attempt  ]8;id=136368;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=506331;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_common.py#351\351]8;;\
#                              1 of 5).
#                              Traceback (most recent call last):
#                                File
#                              "c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\urllib3\con
#                              nectionpool.py", line 790, in urlopen
#                                  response = self._make_request(
#                                File
#                              "c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\urllib3\con
#                              nectionpool.py", line 536, in _make_request
#                                  response = conn.getresponse()
# ...

# %% [markdown]
# ## Events

# %%
events = fbref.read_events(match_id='db261cb0')
events.head()
# Out:
#                                                                            team  \
# league             season game
# ENG-Premier League 2021   2020-09-12 Crystal Palace-Southampton  Crystal Palace
#                           2020-09-12 Crystal Palace-Southampton  Crystal Palace
#                           2020-09-12 Crystal Palace-Southampton     Southampton
#                           2020-09-12 Crystal Palace-Southampton     Southampton
#                           2020-09-12 Crystal Palace-Southampton  Crystal Palace
#
#                                                                 minute score  \
# league             season game
# ENG-Premier League 2021   2020-09-12 Crystal Palace-Southampton     13   1:0
#                           2020-09-12 Crystal Palace-Southampton     41   1:0
#                           2020-09-12 Crystal Palace-Southampton     46   1:0
#                           2020-09-12 Crystal Palace-Southampton     51   1:0
# ...

# %% [markdown]
# ## Shot events

# %%
shots = fbref.read_shot_events(match_id='db261cb0')
shots.head()
# Out:
#                                                                 minute  \
#
# league             season game
# ENG-Premier League 2021   2020-09-12 Crystal Palace-Southampton      4
#                           2020-09-12 Crystal Palace-Southampton     13
#                           2020-09-12 Crystal Palace-Southampton     32
#                           2020-09-12 Crystal Palace-Southampton     36
#                           2020-09-12 Crystal Palace-Southampton     46
#
#                                                                            player  \
#
# league             season game
# ENG-Premier League 2021   2020-09-12 Crystal Palace-Southampton     Jack Stephens
#                           2020-09-12 Crystal Palace-Southampton     Wilfried Zaha
#                           2020-09-12 Crystal Palace-Southampton        Danny Ings
#                           2020-09-12 Crystal Palace-Southampton  Cheikhou Kouyaté
# ...
