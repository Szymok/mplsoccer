# %%
import pandas as pd
import soccerdata as sd
# Out:
# [01/24/24 22:50:56] INFO     No custom team name replacements found. You can configure these in       ]8;id=207540;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=35383;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_config.py#87\87]8;;\
#                              C:\Users\szymo\soccerdata\config\teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=668017;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_config.py\_config.py]8;;\:]8;id=437764;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_config.py#165\165]8;;\
#                              C:\Users\szymo\soccerdata\config\league_dict.json.

# %%
# %env SOCCERDATA_LOGLEVEL=ERROR
# %env SOCCERDATA_NOCACHE=True
# %env SOCCERDATA_NOSTORE=True
# Out:
# env: SOCCERDATA_LOGLEVEL=ERROR
# env: SOCCERDATA_NOCACHE=True
# env: SOCCERDATA_NOSTORE=True

# %% [markdown]
# # FBref

# %%
fbref = sd.FBref(leagues="ESP-La Liga", seasons=2023)
print(fbref.__doc__)
# Out:
# [01/24/24 22:51:02] INFO     Saving cached data to C:\Users\szymo\soccerdata\data\FBref               ]8;id=669970;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=714128;file://c:\Users\szymo\Documents\mplsoccer\.venv\lib\site-packages\soccerdata\_common.py#91\91]8;;\
# Provides pd.DataFrames from data at http://fbref.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/FBref``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include. For efficiently reading data from the Top-5
#         European leagues, use "Big 5 European Leagues Combined".
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or dict or list(dict) or callable, optional
# ...

# %% [markdown]
# ## Team season stats

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="standard")
team_season_stats.reset_index(inplace=True)
team_season_stats.to_csv("data/standard_team_season_stats_spain.csv", index=False)

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="passing")
team_season_stats.reset_index(inplace=True)
team_season_stats.to_csv("data/passing_team_season_stats_spain.csv", index=False)

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="passing_types")
team_season_stats.reset_index(inplace=True)
team_season_stats.to_csv("data/passing_types_team_season_stats_spain.csv", index=False)

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="shooting")
team_season_stats.reset_index(inplace=True)
team_season_stats.to_csv("data/shooting_team_season_stats_spain.csv", index=False)

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="keeper")
team_season_stats.reset_index(inplace=True)
team_season_stats.to_csv("data/keeper_team_season_stats_spain.csv", index=False)

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="keeper_adv")
team_season_stats.reset_index(inplace=True)
team_season_stats.to_csv("data/keeper_adv_team_season_stats_spain.csv", index=False)

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="goal_shot_creation")
team_season_stats.reset_index(inplace=True)
team_season_stats.to_csv("data/goal_shot_creation_team_season_stats_spain.csv", index=False)

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="possession")
team_season_stats.reset_index(inplace=True)
team_season_stats.to_csv("data/possession_team_season_stats_spain.csv", index=False)

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="defense")
team_season_stats.reset_index(inplace=True)
team_season_stats.to_csv("data/defense_team_season_stats_spain.csv", index=False)

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="misc")
team_season_stats.reset_index(inplace=True)
team_season_stats.to_csv("data/misc_team_season_stats_spain.csv", index=False)

# %%
team_season_stats = fbref.read_team_season_stats(stat_type="playing_time")
team_season_stats.reset_index(inplace=True)
team_season_stats.to_csv("data/playing_time_team_season_stats_spain.csv", index=False)

# %% [markdown]
# ## Team match stats

# %%
team_match_stats = fbref.read_team_match_stats(stat_type="shooting", opponent_stats=True)
team_match_stats.head()
# Out:
#                                                                  date  \
#
# league      season team   game
# ESP-La Liga 2324   Alavés 2023-08-14 Alavés-Cádiz          2023-08-14
#                           2023-08-21 Sevilla-Alavés        2023-08-21
#                           2023-08-28 Alavés-Getafe         2023-08-28
#                           2023-09-02 Valencia-Alavés       2023-09-02
#                           2023-09-15 Alavés-Rayo Vallecano 2023-09-15
#
#                                                                   round  day  \
#
# league      season team   game
# ESP-La Liga 2324   Alavés 2023-08-14 Alavés-Cádiz           Matchweek 1  Mon
#                           2023-08-21 Sevilla-Alavés         Matchweek 2  Mon
#                           2023-08-28 Alavés-Getafe          Matchweek 3  Mon
#                           2023-09-02 Valencia-Alavés        Matchweek 4  Sat
#                           2023-09-15 Alavés-Rayo Vallecano  Matchweek 5  Fri
#
# ...

# %% [markdown]
# ## Player season stats

# %%
player_season_stats = fbref.read_player_season_stats(stat_type="standard")
player_season_stats.head()
# Out:
#                                               nation    pos     age  born  \
#
# league      season team   player
# ESP-La Liga 2324   Alavés Abdel Abqar            MAR     DF  24-320  1999
#                           Abderrahman Rebbach    ALG  FW,MF  25-166  1998
#                           Aleksandar Sedlar      SRB     DF  32-042  1991
#                           Alex Sola              ESP  FW,MF  24-229  1999
#                           Ander Guevara          ESP     MF  26-201  1997
#
#                                               Playing Time                     \
#                                                         MP Starts   Min   90s
# league      season team   player
# ESP-La Liga 2324   Alavés Abdel Abqar                   14     14  1254  13.9
#                           Abderrahman Rebbach           16      6   582   6.5
#                           Aleksandar Sedlar             11     11   946  10.5
# ...

# %% [markdown]
# ## Player match stats

# %%
player_match_stats = fbref.read_player_match_stats(stat_type="passing", match_id='872da7fb')
player_match_stats.head()
# Out:
#                                                                                  jersey_number  \
#
# league      season game                         team       player
# ESP-La Liga 2324   2023-12-09 Betis-Real Madrid Real Betis Abdessamad Ezzalzouli             7
#                                                            Abner                            20
#                                                            Aitor Ruibal                     24
#                                                            Andrés Guardado                  18
#                                                            Assane Diao                      38
#
#                                                                                  nation  \
#
# league      season game                         team       player
# ESP-La Liga 2324   2023-12-09 Betis-Real Madrid Real Betis Abdessamad Ezzalzouli    MAR
#                                                            Abner                    BRA
# ...

# %% [markdown]
# ## Game schedule

# %%
epl_schedule = fbref.read_schedule()
epl_schedule.head()
# Out:
#                                                          week  day       date  \
# league      season game
# ESP-La Liga 2324   2023-08-11 Almería-Rayo Vallecano        1  Fri 2023-08-11
#                    2023-08-11 Sevilla-Valencia              1  Fri 2023-08-11
#                    2023-08-12 Athletic Club-Real Madrid     1  Sat 2023-08-12
#                    2023-08-12 Las Palmas-Mallorca           1  Sat 2023-08-12
#                    2023-08-12 Real Sociedad-Girona          1  Sat 2023-08-12
#
#                                                           time      home_team  \
# league      season game
# ESP-La Liga 2324   2023-08-11 Almería-Rayo Vallecano     19:30        Almería
#                    2023-08-11 Sevilla-Valencia           22:00        Sevilla
#                    2023-08-12 Athletic Club-Real Madrid  21:30  Athletic Club
#                    2023-08-12 Las Palmas-Mallorca        18:30     Las Palmas
# ...
